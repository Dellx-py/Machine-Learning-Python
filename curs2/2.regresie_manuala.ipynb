# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
apartamente = [(37, 65), (55, 80), (80, 120), (60, 95), (92, 205), (41, 75), (170, 400), (145, 367), (82, 205), (72, 198)]

apartamente = np.array(apartamente)

apartamente = apartamente[apartamente[:, 0].argsort()]
suprafete, preturi = apartamente[:, 0], apartamente[:, 1]

# %%
def lin_plot(x, y, a, b):
    plt.scatter(x, y);
    f = lambda x: a * x + b
    plt.plot(x, list(map(f, x)));

# %%
lin_plot(suprafete, preturi, 0, 0)

# %%
lin_plot(x=suprafete, y=preturi, a=1, b=30)

# %%
preturi
# Out:
# array([ 65,  75,  80,  95, 198, 120, 205, 205, 367, 400])

# %%
suprafete
# Out:
# array([ 40,  44,  58,  63,  75,  83,  85,  95, 148, 173])

# %%
a = 1
b = 1
preturi_calculate = a * suprafete + 1
preturi_calculate
# Out:
# array([ 41,  45,  59,  64,  76,  84,  86,  96, 149, 174])

# %%
preturi - preturi_calculate
# Out:
# array([ 24,  30,  21,  31, 122,  36, 119, 109, 218, 226])

# %%
(preturi - preturi_calculate) ** 2
# Out:
# array([  576,   900,   441,   961, 14884,  1296, 14161, 11881, 47524,
#        51076])

# %%
((preturi - preturi_calculate) ** 2).sum()
# Out:
# np.int64(143700)

# %%
np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# np.float64(379.0778284204973)

# %%
a = 2
b = 1
preturi_calculate = a * suprafete + b
preturi_calculate
np.sqrt(((preturi - preturi_calculate) ** 2).sum())
# Out:
# np.float64(127.7654100294755)

# %%
lin_plot(x=suprafete, y=preturi, 2, 1)
# Out:
#   Cell In[54], line 1
#     lin_plot(x=suprafete, y=preturi, 2, 1)
#                                          ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# incepem cu a si b - random (sau 0 si 0)
# 2. ajustam pe a si b
