# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import make_regression

# %%
make_regression(n_samples=2, n_features=1)
# Out:
# (array([[ 0.05170973],
#         [-0.39732055]]),
#  array([  4.13507906, -31.77258558]))

# %%
make_regression(n_samples=3, n_features=2)
# Out:
# (array([[-0.82848429, -0.80374806],
#         [-0.17403286, -1.2528645 ],
#         [-1.03738795, -2.01432716]]),
#  array([ -63.54477255,  -44.53529077, -108.56486097]))

# %%
x, y = make_regression(n_samples=10, n_features=1)
plt.scatter(x, y)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, y)
plt.plot(x, model.coef_ * x + model.intercept_);

# %% [markdown]
# Adaugare Noise (zgomot)

# %%
x, y = make_regression(n_samples=100, n_features=1, noise=10)
model = LinearRegression()
model.fit(x, y)
plt.scatter(x, y)
plt.plot(x, model.coef_ * x + model.intercept_);

# %%
model.predict([[1]])
# Out:
# array([31.05648136])

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x, y)
# Out:
# KNeighborsRegressor()

# %%
knn_model.predict([[1]])
# Out:
# array([35.92915927])
